# %% [markdown]
# ## About Me Lab: AI Engineering, Data Analytics & Data Science
#
# In this notebook, you'll write a short introduction about yourself using Python!
#
# ### Instructions:
# - Fill in the variables below with your details.
# - Run the cell to print your introduction.
#
# ### What to Include:
# - Your name.
# - Why you're interested in AI Engineering, Data Analytics or Data Science.
# - A fun fact about yourself or a goal for this course.

# %%
# About Me
# Please fill in the following details.

name = "Sabeur Zarai"
reason = "AI represents the next major shift in software engineering, and I'm excited to combine my development background with modern AI technologies to build intelligent applications."
fun_fact = "After 13 years of coding, I spent four years as an agile coach—now I'm back to coding, and this time I'm teaching machines to think."

print(f"Hi! My name is {name}. I’m excited to learn because {reason}. A fun fact about me is: {fun_fact}.")
# Out:
# Hi! My name is Sabeur Zarai. I’m excited to learn because AI represents the next major shift in software engineering, and I'm excited to combine my development background with modern AI technologies to build intelligent applications.. A fun fact about me is: After 13 years of coding, I spent four years as an agile coach—now I'm back to coding, and this time I'm teaching machines to think..
